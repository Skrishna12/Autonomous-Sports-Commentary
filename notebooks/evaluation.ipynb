# %% [markdown]
# # Commentary evaluation
#
# Logs prompt version, model, and judge scores. Run `python eval/run_eval.py` for a full table. Do not change prompts without logging an MLflow run first.

# %%
from eval.run_eval import main
main()
